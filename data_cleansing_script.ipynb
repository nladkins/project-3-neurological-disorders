# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import create_engine
import sqlalchemy
from sqlalchemy import Column, Integer, String, Float, Date
from sqlalchemy import Table
from sqlalchemy.ext.declarative import declarative_base
from secret import password

# %%
adhd_df = pd.read_csv('raw-data/adhd_raw.csv')
asperger_df = pd.read_csv('raw-data/asperger_raw.csv')
autism_df = pd.read_csv('raw-data/autism_raw.csv')
idd_df = pd.read_csv('raw-data/idd_raw.csv')

# %% [markdown]
# # Cleaning ADHD Data

# %%
adhd_df.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1990
# 2  Afghanistan       AFG  1991
# 3  Afghanistan       AFG  1992
# 4  Afghanistan       AFG  1993
#
#    Prevalence - Attention-deficit/hyperactivity disorder - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           1.559695
# 2                                           1.560023
# 3                                           1.560413
# 4                                           1.560768
#
#    Prevalence - Attention-deficit/hyperactivity disorder - Sex: Female - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           0.683613
# 2                                           0.683845
# 3                                           0.684081
# 4                                           0.684330
#
#    Population (historical estimates) Continent
# 0                                NaN      Asia
# 1                         12412311.0       NaN
# 2                         13299016.0       NaN
# 3                         14485543.0       NaN
# 4                         15816601.0       NaN

# %%
# we're only focusing on years 1990+, no other values so we're filtering the rows with numbers other than 1990+
adhd_df_filtered = adhd_df[adhd_df['Year'] >= 1990]

# dropping continent column as this is where a lot of our NaN values are coming from
adhd_df_filtered = adhd_df_filtered.drop(columns = 'Continent')
adhd_df_filtered
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56624       Zimbabwe       ZWE  2018
# 56625       Zimbabwe       ZWE  2019
# 56626       Zimbabwe       ZWE  2020
# 56627       Zimbabwe       ZWE  2021
# 56628  Åland Islands       ALA  2015
#
#        Prevalence - Attention-deficit/hyperactivity disorder - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                               1.559695
# 2                                               1.560023
# 3                                               1.560413
# 4                                               1.560768
# ...                                                  ...
# 56624                                                NaN
# 56625                                                NaN
# 56626                                                NaN
# 56627                                                NaN
# 56628                                                NaN
#
#        Prevalence - Attention-deficit/hyperactivity disorder - Sex: Female - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                               0.683613
# 2                                               0.683845
# 3                                               0.684081
# 4                                               0.684330
# ...                                                  ...
# 56624                                                NaN
# 56625                                                NaN
# 56626                                                NaN
# 56627                                                NaN
# 56628                                                NaN
#
#        Population (historical estimates)
# 0                                    NaN
# 1                             12412311.0
# 2                             13299016.0
# 3                             14485543.0
# 4                             15816601.0
# ...                                  ...
# 56624                         14438812.0
# 56625                         14645473.0
# 56626                         14862927.0
# 56627                         15092171.0
# 56628                                NaN
#
# [8755 rows x 6 columns]

# %%
# dropping all NA values
adhd_df_filtered = adhd_df_filtered.dropna()

# %%
adhd_df_filtered.head()
# Out:
#         Entity Code  Year  \
# 1  Afghanistan  AFG  1990
# 2  Afghanistan  AFG  1991
# 3  Afghanistan  AFG  1992
# 4  Afghanistan  AFG  1993
# 5  Afghanistan  AFG  1994
#
#    Prevalence - Attention-deficit/hyperactivity disorder - Sex: Male - Age: Age-standardized (Percent)  \
# 1                                           1.559695
# 2                                           1.560023
# 3                                           1.560413
# 4                                           1.560768
# 5                                           1.561178
#
#    Prevalence - Attention-deficit/hyperactivity disorder - Sex: Female - Age: Age-standardized (Percent)  \
# 1                                           0.683613
# 2                                           0.683845
# 3                                           0.684081
# 4                                           0.684330
# 5                                           0.684579
#
#    Population (historical estimates)
# 1                         12412311.0
# 2                         13299016.0
# 3                         14485543.0
# 4                         15816601.0
# 5                         17075728.0

# %%
# checking data types of values
adhd_df_filtered.dtypes
# Out:
# Entity                                                                                                    object
# Code                                                                                                      object
# Year                                                                                                       int64
# Prevalence - Attention-deficit/hyperactivity disorder - Sex: Male - Age: Age-standardized (Percent)      float64
# Prevalence - Attention-deficit/hyperactivity disorder - Sex: Female - Age: Age-standardized (Percent)    float64
# Population (historical estimates)                                                                        float64
# dtype: object

# %%
# changing prevalence column names
adhd_df_filtered = adhd_df_filtered.rename(columns = {
    'Prevalence - Attention-deficit/hyperactivity disorder - Sex: Male - Age: Age-standardized (Percent)': 'Prevalance_In_Males',
'Prevalence - Attention-deficit/hyperactivity disorder - Sex: Female - Age: Age-standardized (Percent)': 'Prevalance_In_Females',
'Population (historical estimates)': 'Population'})

# %%
# adding column defining diagnosis
adhd_df_filtered['Diagnosis'] = 'ADHD'
adhd_df_filtered
# Out:
#             Entity Code  Year  Prevalance_In_Males  Prevalance_In_Females  \
# 1      Afghanistan  AFG  1990             1.559695               0.683613
# 2      Afghanistan  AFG  1991             1.560023               0.683845
# 3      Afghanistan  AFG  1992             1.560413               0.684081
# 4      Afghanistan  AFG  1993             1.560768               0.684330
# 5      Afghanistan  AFG  1994             1.561178               0.684579
# ...            ...  ...   ...                  ...                    ...
# 56392     Zimbabwe  ZWE  2013             1.929572               0.836387
# 56393     Zimbabwe  ZWE  2014             1.932201               0.836935
# 56394     Zimbabwe  ZWE  2015             1.935371               0.837626
# 56395     Zimbabwe  ZWE  2016             1.939094               0.838419
# 56396     Zimbabwe  ZWE  2017             1.943416               0.839335
#
#        Population Diagnosis
# 1      12412311.0      ADHD
# 2      13299016.0      ADHD
# 3      14485543.0      ADHD
# 4      15816601.0      ADHD
# 5      17075728.0      ADHD
# ...           ...       ...
# 56392  13350378.0      ADHD
# 56393  13586710.0      ADHD
# 56394  13814642.0      ADHD
# 56395  14030338.0      ADHD
# 56396  14236599.0      ADHD
#
# [5488 rows x 7 columns]

# %% [markdown]
# # Cleaning Asperger's Data

# %%
asperger_df.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1990
# 2  Afghanistan       AFG  1991
# 3  Afghanistan       AFG  1992
# 4  Afghanistan       AFG  1993
#
#    Prevalence - Asperger syndrome and other autistic spectrum disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           1.045411
# 2                                           1.045548
# 3                                           1.045715
# 4                                           1.045770
#
#    Prevalence - Asperger syndrome and other autistic spectrum disorders - Sex: Female - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           0.236704
# 2                                           0.236713
# 3                                           0.236731
# 4                                           0.236749
#
#    Population (historical estimates) Continent
# 0                                NaN      Asia
# 1                         12412311.0       NaN
# 2                         13299016.0       NaN
# 3                         14485543.0       NaN
# 4                         15816601.0       NaN

# %%
# we're only focusing on years 1990+, no other values so we're filtering the rows with numbers other than 1990+
asperger_df_filtered = asperger_df[asperger_df['Year'] >= 1990]

# dropping continent column as this is where a lot of our NaN values are coming from
asperger_df_filtered = asperger_df_filtered.drop(columns = 'Continent')
asperger_df_filtered
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56510       Zimbabwe       ZWE  2018
# 56511       Zimbabwe       ZWE  2019
# 56512       Zimbabwe       ZWE  2020
# 56513       Zimbabwe       ZWE  2021
# 56514  Åland Islands       ALA  2015
#
#        Prevalence - Asperger syndrome and other autistic spectrum disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                               1.045411
# 2                                               1.045548
# 3                                               1.045715
# 4                                               1.045770
# ...                                                  ...
# 56510                                                NaN
# 56511                                                NaN
# 56512                                                NaN
# 56513                                                NaN
# 56514                                                NaN
#
#        Prevalence - Asperger syndrome and other autistic spectrum disorders - Sex: Female - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                               0.236704
# 2                                               0.236713
# 3                                               0.236731
# 4                                               0.236749
# ...                                                  ...
# 56510                                                NaN
# 56511                                                NaN
# 56512                                                NaN
# 56513                                                NaN
# 56514                                                NaN
#
#        Population (historical estimates)
# 0                                    NaN
# 1                             12412311.0
# 2                             13299016.0
# 3                             14485543.0
# 4                             15816601.0
# ...                                  ...
# 56510                         14438812.0
# 56511                         14645473.0
# 56512                         14862927.0
# 56513                         15092171.0
# 56514                                NaN
#
# [8641 rows x 6 columns]

# %%
# dropping all NA values
asperger_df_filtered = asperger_df_filtered.dropna()

# %%
asperger_df_filtered
# Out:
#             Entity Code  Year  \
# 1      Afghanistan  AFG  1990
# 2      Afghanistan  AFG  1991
# 3      Afghanistan  AFG  1992
# 4      Afghanistan  AFG  1993
# 5      Afghanistan  AFG  1994
# ...            ...  ...   ...
# 56277     Zimbabwe  ZWE  2012
# 56278     Zimbabwe  ZWE  2013
# 56279     Zimbabwe  ZWE  2014
# 56280     Zimbabwe  ZWE  2015
# 56281     Zimbabwe  ZWE  2016
#
#        Prevalence - Asperger syndrome and other autistic spectrum disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 1                                               1.045411
# 2                                               1.045548
# 3                                               1.045715
# 4                                               1.045770
# 5                                               1.045838
# ...                                                  ...
# 56277                                           0.972759
# 56278                                           0.973844
# 56279                                           0.974740
# 56280                                           0.975532
# 56281                                           0.976319
#
#        Prevalence - Asperger syndrome and other autistic spectrum disorders - Sex: Female - Age: Age-standardized (Percent)  \
# 1                                               0.236704
# 2                                               0.236713
# 3                                               0.236731
# 4                                               0.236749
# 5                                               0.236751
# ...                                                  ...
# 56277                                           0.217398
# 56278                                           0.217514
# 56279                                           0.217633
# 56280                                           0.217741
# 56281                                           0.217850
#
#        Population (historical estimates)
# 1                             12412311.0
# 2                             13299016.0
# 3                             14485543.0
# 4                             15816601.0
# 5                             17075728.0
# ...                                  ...
# 56277                         13115149.0
# 56278                         13350378.0
# 56279                         13586710.0
# 56280                         13814642.0
# 56281                         14030338.0
#
# [5292 rows x 6 columns]

# %%
# checking data types of values
asperger_df_filtered.dtypes
# Out:
# Entity                                                                                                                   object
# Code                                                                                                                     object
# Year                                                                                                                      int64
# Prevalence - Asperger syndrome and other autistic spectrum disorders - Sex: Male - Age: Age-standardized (Percent)      float64
# Prevalence - Asperger syndrome and other autistic spectrum disorders - Sex: Female - Age: Age-standardized (Percent)    float64
# Population (historical estimates)                                                                                       float64
# dtype: object

# %%
# changing prevalence column names
asperger_df_filtered = asperger_df_filtered.rename(columns = {
    'Prevalence - Asperger syndrome and other autistic spectrum disorders - Sex: Male - Age: Age-standardized (Percent)': 'Prevalance_In_Males',
'Prevalence - Asperger syndrome and other autistic spectrum disorders - Sex: Female - Age: Age-standardized (Percent)': 'Prevalance_In_Females',
'Population (historical estimates)': 'Population'})

# %%
asperger_df_filtered
# Out:
#             Entity Code  Year  Prevalance_In_Males  Prevalance_In_Females  \
# 1      Afghanistan  AFG  1990             1.045411               0.236704
# 2      Afghanistan  AFG  1991             1.045548               0.236713
# 3      Afghanistan  AFG  1992             1.045715               0.236731
# 4      Afghanistan  AFG  1993             1.045770               0.236749
# 5      Afghanistan  AFG  1994             1.045838               0.236751
# ...            ...  ...   ...                  ...                    ...
# 56277     Zimbabwe  ZWE  2012             0.972759               0.217398
# 56278     Zimbabwe  ZWE  2013             0.973844               0.217514
# 56279     Zimbabwe  ZWE  2014             0.974740               0.217633
# 56280     Zimbabwe  ZWE  2015             0.975532               0.217741
# 56281     Zimbabwe  ZWE  2016             0.976319               0.217850
#
#        Population
# 1      12412311.0
# 2      13299016.0
# 3      14485543.0
# 4      15816601.0
# 5      17075728.0
# ...           ...
# 56277  13115149.0
# 56278  13350378.0
# 56279  13586710.0
# 56280  13814642.0
# 56281  14030338.0
#
# [5292 rows x 6 columns]

# %%
# adding column defining diagnosis
asperger_df_filtered['Diagnosis'] = 'Asperger'
asperger_df_filtered
# Out:
#             Entity Code  Year  Prevalance_In_Males  Prevalance_In_Females  \
# 1      Afghanistan  AFG  1990             1.045411               0.236704
# 2      Afghanistan  AFG  1991             1.045548               0.236713
# 3      Afghanistan  AFG  1992             1.045715               0.236731
# 4      Afghanistan  AFG  1993             1.045770               0.236749
# 5      Afghanistan  AFG  1994             1.045838               0.236751
# ...            ...  ...   ...                  ...                    ...
# 56277     Zimbabwe  ZWE  2012             0.972759               0.217398
# 56278     Zimbabwe  ZWE  2013             0.973844               0.217514
# 56279     Zimbabwe  ZWE  2014             0.974740               0.217633
# 56280     Zimbabwe  ZWE  2015             0.975532               0.217741
# 56281     Zimbabwe  ZWE  2016             0.976319               0.217850
#
#        Population Diagnosis
# 1      12412311.0  Asperger
# 2      13299016.0  Asperger
# 3      14485543.0  Asperger
# 4      15816601.0  Asperger
# 5      17075728.0  Asperger
# ...           ...       ...
# 56277  13115149.0  Asperger
# 56278  13350378.0  Asperger
# 56279  13586710.0  Asperger
# 56280  13814642.0  Asperger
# 56281  14030338.0  Asperger
#
# [5292 rows x 7 columns]

# %% [markdown]
# # Cleaning Autism Data

# %%
autism_df.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1990
# 2  Afghanistan       AFG  1991
# 3  Afghanistan       AFG  1992
# 4  Afghanistan       AFG  1993
#
#    Prevalence - Autism - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           0.313685
# 2                                           0.312901
# 3                                           0.312296
# 4                                           0.311659
#
#    Prevalence - Autism - Sex: Female - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           0.129473
# 2                                           0.128978
# 3                                           0.128577
# 4                                           0.128190
#
#    Population (historical estimates) Continent
# 0                                NaN      Asia
# 1                         12412311.0       NaN
# 2                         13299016.0       NaN
# 3                         14485543.0       NaN
# 4                         15816601.0       NaN

# %%
# we're only focusing on years 1990+, no other values so we're filtering the rows with numbers other than 1990+
autism_df_filtered = autism_df[autism_df['Year'] >= 1990]

# dropping continent column as this is where a lot of our NaN values are coming from
autism_df_filtered = autism_df_filtered.drop(columns = 'Continent')
autism_df_filtered
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56510       Zimbabwe       ZWE  2018
# 56511       Zimbabwe       ZWE  2019
# 56512       Zimbabwe       ZWE  2020
# 56513       Zimbabwe       ZWE  2021
# 56514  Åland Islands       ALA  2015
#
#        Prevalence - Autism - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                               0.313685
# 2                                               0.312901
# 3                                               0.312296
# 4                                               0.311659
# ...                                                  ...
# 56510                                                NaN
# 56511                                                NaN
# 56512                                                NaN
# 56513                                                NaN
# 56514                                                NaN
#
#        Prevalence - Autism - Sex: Female - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                               0.129473
# 2                                               0.128978
# 3                                               0.128577
# 4                                               0.128190
# ...                                                  ...
# 56510                                                NaN
# 56511                                                NaN
# 56512                                                NaN
# 56513                                                NaN
# 56514                                                NaN
#
#        Population (historical estimates)
# 0                                    NaN
# 1                             12412311.0
# 2                             13299016.0
# 3                             14485543.0
# 4                             15816601.0
# ...                                  ...
# 56510                         14438812.0
# 56511                         14645473.0
# 56512                         14862927.0
# 56513                         15092171.0
# 56514                                NaN
#
# [8641 rows x 6 columns]

# %%
# dropping all NA values
autism_df_filtered = autism_df_filtered.dropna()

# %%
autism_df_filtered
# Out:
#             Entity Code  Year  \
# 1      Afghanistan  AFG  1990
# 2      Afghanistan  AFG  1991
# 3      Afghanistan  AFG  1992
# 4      Afghanistan  AFG  1993
# 5      Afghanistan  AFG  1994
# ...            ...  ...   ...
# 56277     Zimbabwe  ZWE  2012
# 56278     Zimbabwe  ZWE  2013
# 56279     Zimbabwe  ZWE  2014
# 56280     Zimbabwe  ZWE  2015
# 56281     Zimbabwe  ZWE  2016
#
#        Prevalence - Autism - Sex: Male - Age: Age-standardized (Percent)  \
# 1                                               0.313685
# 2                                               0.312901
# 3                                               0.312296
# 4                                               0.311659
# 5                                               0.311027
# ...                                                  ...
# 56277                                           0.304222
# 56278                                           0.304556
# 56279                                           0.304831
# 56280                                           0.305075
# 56281                                           0.305508
#
#        Prevalence - Autism - Sex: Female - Age: Age-standardized (Percent)  \
# 1                                               0.129473
# 2                                               0.128978
# 3                                               0.128577
# 4                                               0.128190
# 5                                               0.127810
# ...                                                  ...
# 56277                                           0.138132
# 56278                                           0.138163
# 56279                                           0.138197
# 56280                                           0.138223
# 56281                                           0.138323
#
#        Population (historical estimates)
# 1                             12412311.0
# 2                             13299016.0
# 3                             14485543.0
# 4                             15816601.0
# 5                             17075728.0
# ...                                  ...
# 56277                         13115149.0
# 56278                         13350378.0
# 56279                         13586710.0
# 56280                         13814642.0
# 56281                         14030338.0
#
# [5292 rows x 6 columns]

# %%
# checking data types of values
autism_df_filtered.dtypes
# Out:
# Entity                                                                  object
# Code                                                                    object
# Year                                                                     int64
# Prevalence - Autism - Sex: Male - Age: Age-standardized (Percent)      float64
# Prevalence - Autism - Sex: Female - Age: Age-standardized (Percent)    float64
# Population (historical estimates)                                      float64
# dtype: object

# %%
# changing prevalence column names
autism_df_filtered = autism_df_filtered.rename(columns = {
    'Prevalence - Autism - Sex: Male - Age: Age-standardized (Percent)': 'Prevalance_In_Males',
'Prevalence - Autism - Sex: Female - Age: Age-standardized (Percent)': 'Prevalance_In_Females',
'Population (historical estimates)': 'Population'})

# %%
autism_df_filtered
# Out:
#             Entity Code  Year  Prevalance_In_Males  Prevalance_In_Females  \
# 1      Afghanistan  AFG  1990             0.313685               0.129473
# 2      Afghanistan  AFG  1991             0.312901               0.128978
# 3      Afghanistan  AFG  1992             0.312296               0.128577
# 4      Afghanistan  AFG  1993             0.311659               0.128190
# 5      Afghanistan  AFG  1994             0.311027               0.127810
# ...            ...  ...   ...                  ...                    ...
# 56277     Zimbabwe  ZWE  2012             0.304222               0.138132
# 56278     Zimbabwe  ZWE  2013             0.304556               0.138163
# 56279     Zimbabwe  ZWE  2014             0.304831               0.138197
# 56280     Zimbabwe  ZWE  2015             0.305075               0.138223
# 56281     Zimbabwe  ZWE  2016             0.305508               0.138323
#
#        Population
# 1      12412311.0
# 2      13299016.0
# 3      14485543.0
# 4      15816601.0
# 5      17075728.0
# ...           ...
# 56277  13115149.0
# 56278  13350378.0
# 56279  13586710.0
# 56280  13814642.0
# 56281  14030338.0
#
# [5292 rows x 6 columns]

# %%
# adding column defining diagnosis
autism_df_filtered['Diagnosis'] = 'Autism'
autism_df_filtered
# Out:
#             Entity Code  Year  Prevalance_In_Males  Prevalance_In_Females  \
# 1      Afghanistan  AFG  1990             0.313685               0.129473
# 2      Afghanistan  AFG  1991             0.312901               0.128978
# 3      Afghanistan  AFG  1992             0.312296               0.128577
# 4      Afghanistan  AFG  1993             0.311659               0.128190
# 5      Afghanistan  AFG  1994             0.311027               0.127810
# ...            ...  ...   ...                  ...                    ...
# 56277     Zimbabwe  ZWE  2012             0.304222               0.138132
# 56278     Zimbabwe  ZWE  2013             0.304556               0.138163
# 56279     Zimbabwe  ZWE  2014             0.304831               0.138197
# 56280     Zimbabwe  ZWE  2015             0.305075               0.138223
# 56281     Zimbabwe  ZWE  2016             0.305508               0.138323
#
#        Population Diagnosis
# 1      12412311.0    Autism
# 2      13299016.0    Autism
# 3      14485543.0    Autism
# 4      15816601.0    Autism
# 5      17075728.0    Autism
# ...           ...       ...
# 56277  13115149.0    Autism
# 56278  13350378.0    Autism
# 56279  13586710.0    Autism
# 56280  13814642.0    Autism
# 56281  14030338.0    Autism
#
# [5292 rows x 7 columns]

# %% [markdown]
# # Cleaning Intellectual Disability Data

# %%
idd_df.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1990
# 2  Afghanistan       AFG  1991
# 3  Afghanistan       AFG  1992
# 4  Afghanistan       AFG  1993
#
#    Prevalence - Idiopathic developmental intellectual disability - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           5.716282
# 2                                           6.082564
# 3                                           6.409605
# 4                                           6.673168
#
#    Prevalence - Idiopathic developmental intellectual disability - Sex: Female - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           4.635575
# 2                                           4.917924
# 3                                           5.170105
# 4                                           5.373784
#
#    Population (historical estimates) Continent
# 0                                NaN      Asia
# 1                         12412311.0       NaN
# 2                         13299016.0       NaN
# 3                         14485543.0       NaN
# 4                         15816601.0       NaN

# %%
# we're only focusing on years 1990+, no other values so we're filtering the rows with numbers other than 1990+
idd_df_filtered = idd_df[idd_df['Year'] >= 1990]

# dropping continent column as this is where a lot of our NaN values are coming from
idd_df_filtered = idd_df_filtered.drop(columns = 'Continent')
idd_df_filtered
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56624       Zimbabwe       ZWE  2018
# 56625       Zimbabwe       ZWE  2019
# 56626       Zimbabwe       ZWE  2020
# 56627       Zimbabwe       ZWE  2021
# 56628  Åland Islands       ALA  2015
#
#        Prevalence - Idiopathic developmental intellectual disability - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                               5.716282
# 2                                               6.082564
# 3                                               6.409605
# 4                                               6.673168
# ...                                                  ...
# 56624                                                NaN
# 56625                                                NaN
# 56626                                                NaN
# 56627                                                NaN
# 56628                                                NaN
#
#        Prevalence - Idiopathic developmental intellectual disability - Sex: Female - Age: Age-standardized (Percent)  \
# 0                                                    NaN
# 1                                               4.635575
# 2                                               4.917924
# 3                                               5.170105
# 4                                               5.373784
# ...                                                  ...
# 56624                                                NaN
# 56625                                                NaN
# 56626                                                NaN
# 56627                                                NaN
# 56628                                                NaN
#
#        Population (historical estimates)
# 0                                    NaN
# 1                             12412311.0
# 2                             13299016.0
# 3                             14485543.0
# 4                             15816601.0
# ...                                  ...
# 56624                         14438812.0
# 56625                         14645473.0
# 56626                         14862927.0
# 56627                         15092171.0
# 56628                                NaN
#
# [8755 rows x 6 columns]

# %%
# dropping all NA values
idd_df_filtered = idd_df_filtered.dropna()

# %%
idd_df_filtered
# Out:
#             Entity Code  Year  \
# 1      Afghanistan  AFG  1990
# 2      Afghanistan  AFG  1991
# 3      Afghanistan  AFG  1992
# 4      Afghanistan  AFG  1993
# 5      Afghanistan  AFG  1994
# ...            ...  ...   ...
# 56392     Zimbabwe  ZWE  2013
# 56393     Zimbabwe  ZWE  2014
# 56394     Zimbabwe  ZWE  2015
# 56395     Zimbabwe  ZWE  2016
# 56396     Zimbabwe  ZWE  2017
#
#        Prevalence - Idiopathic developmental intellectual disability - Sex: Male - Age: Age-standardized (Percent)  \
# 1                                               5.716282
# 2                                               6.082564
# 3                                               6.409605
# 4                                               6.673168
# 5                                               6.849740
# ...                                                  ...
# 56392                                           0.676245
# 56393                                           0.668882
# 56394                                           0.657862
# 56395                                           0.642503
# 56396                                           0.622132
#
#        Prevalence - Idiopathic developmental intellectual disability - Sex: Female - Age: Age-standardized (Percent)  \
# 1                                               4.635575
# 2                                               4.917924
# 3                                               5.170105
# 4                                               5.373784
# 5                                               5.510409
# ...                                                  ...
# 56392                                           0.635314
# 56393                                           0.627092
# 56394                                           0.615192
# 56395                                           0.598988
# 56396                                           0.577887
#
#        Population (historical estimates)
# 1                             12412311.0
# 2                             13299016.0
# 3                             14485543.0
# 4                             15816601.0
# 5                             17075728.0
# ...                                  ...
# 56392                         13350378.0
# 56393                         13586710.0
# 56394                         13814642.0
# 56395                         14030338.0
# 56396                         14236599.0
#
# [5488 rows x 6 columns]

# %%
# checking data types of values
idd_df_filtered.dtypes
# Out:
# Entity                                                                                                            object
# Code                                                                                                              object
# Year                                                                                                               int64
# Prevalence - Idiopathic developmental intellectual disability - Sex: Male - Age: Age-standardized (Percent)      float64
# Prevalence - Idiopathic developmental intellectual disability - Sex: Female - Age: Age-standardized (Percent)    float64
# Population (historical estimates)                                                                                float64
# dtype: object

# %%
# changing prevalence column names
idd_df_filtered = idd_df_filtered.rename(columns = {
    'Prevalence - Idiopathic developmental intellectual disability - Sex: Male - Age: Age-standardized (Percent)': 'Prevalance_In_Males',
'Prevalence - Idiopathic developmental intellectual disability - Sex: Female - Age: Age-standardized (Percent)': 'Prevalance_In_Females',
'Population (historical estimates)': 'Population'})

# %%
idd_df_filtered
# Out:
#             Entity Code  Year  Prevalance_In_Males  Prevalance_In_Females  \
# 1      Afghanistan  AFG  1990             5.716282               4.635575
# 2      Afghanistan  AFG  1991             6.082564               4.917924
# 3      Afghanistan  AFG  1992             6.409605               5.170105
# 4      Afghanistan  AFG  1993             6.673168               5.373784
# 5      Afghanistan  AFG  1994             6.849740               5.510409
# ...            ...  ...   ...                  ...                    ...
# 56392     Zimbabwe  ZWE  2013             0.676245               0.635314
# 56393     Zimbabwe  ZWE  2014             0.668882               0.627092
# 56394     Zimbabwe  ZWE  2015             0.657862               0.615192
# 56395     Zimbabwe  ZWE  2016             0.642503               0.598988
# 56396     Zimbabwe  ZWE  2017             0.622132               0.577887
#
#        Population
# 1      12412311.0
# 2      13299016.0
# 3      14485543.0
# 4      15816601.0
# 5      17075728.0
# ...           ...
# 56392  13350378.0
# 56393  13586710.0
# 56394  13814642.0
# 56395  14030338.0
# 56396  14236599.0
#
# [5488 rows x 6 columns]

# %%
# adding column defining diagnosis
idd_df_filtered['Diagnosis'] = 'IDD'
idd_df_filtered
# Out:
#             Entity Code  Year  Prevalance_In_Males  Prevalance_In_Females  \
# 1      Afghanistan  AFG  1990             5.716282               4.635575
# 2      Afghanistan  AFG  1991             6.082564               4.917924
# 3      Afghanistan  AFG  1992             6.409605               5.170105
# 4      Afghanistan  AFG  1993             6.673168               5.373784
# 5      Afghanistan  AFG  1994             6.849740               5.510409
# ...            ...  ...   ...                  ...                    ...
# 56392     Zimbabwe  ZWE  2013             0.676245               0.635314
# 56393     Zimbabwe  ZWE  2014             0.668882               0.627092
# 56394     Zimbabwe  ZWE  2015             0.657862               0.615192
# 56395     Zimbabwe  ZWE  2016             0.642503               0.598988
# 56396     Zimbabwe  ZWE  2017             0.622132               0.577887
#
#        Population Diagnosis
# 1      12412311.0       IDD
# 2      13299016.0       IDD
# 3      14485543.0       IDD
# 4      15816601.0       IDD
# 5      17075728.0       IDD
# ...           ...       ...
# 56392  13350378.0       IDD
# 56393  13586710.0       IDD
# 56394  13814642.0       IDD
# 56395  14030338.0       IDD
# 56396  14236599.0       IDD
#
# [5488 rows x 7 columns]

# %%
# combining all dataframes together to be exported to csv file and postgres
# added index column to be named as primary key for postgres
tables = [adhd_df_filtered, asperger_df_filtered, autism_df_filtered, idd_df_filtered]
final_table = pd.concat(tables, ignore_index=True, sort=True)
final_table.reset_index(inplace=True)
final_table
# Out:
#        index Code Diagnosis       Entity  Population  Prevalance_In_Females  \
# 0          0  AFG      ADHD  Afghanistan  12412311.0               0.683613
# 1          1  AFG      ADHD  Afghanistan  13299016.0               0.683845
# 2          2  AFG      ADHD  Afghanistan  14485543.0               0.684081
# 3          3  AFG      ADHD  Afghanistan  15816601.0               0.684330
# 4          4  AFG      ADHD  Afghanistan  17075728.0               0.684579
# ...      ...  ...       ...          ...         ...                    ...
# 21555  21555  ZWE       IDD     Zimbabwe  13350378.0               0.635314
# 21556  21556  ZWE       IDD     Zimbabwe  13586710.0               0.627092
# 21557  21557  ZWE       IDD     Zimbabwe  13814642.0               0.615192
# 21558  21558  ZWE       IDD     Zimbabwe  14030338.0               0.598988
# 21559  21559  ZWE       IDD     Zimbabwe  14236599.0               0.577887
#
#        Prevalance_In_Males  Year
# 0                 1.559695  1990
# 1                 1.560023  1991
# 2                 1.560413  1992
# 3                 1.560768  1993
# 4                 1.561178  1994
# ...                    ...   ...
# 21555             0.676245  2013
# 21556             0.668882  2014
# 21557             0.657862  2015
# 21558             0.642503  2016
# 21559             0.622132  2017
#
# [21560 rows x 8 columns]

# %%
# create class for "final_table"

Base = declarative_base()

class neuroDiagnosis(Base):
    __tablename__ = 'disorders'
    index = Column(Integer(), primary_key = True)
    code = Column(String())
    diagnosis = Column(String())
    entity = Column(String())
    population = Column(Float())
    prevalence_in_females = Column(Float())
    prevalence_in_males = Column(Float())
    year = Column(Integer())

# %%
# our password to get into postgres is needed, to keep password from being exposed, the .py file has been placed in
# a .gitignore file
from secret import password

# Export df to Postgres
# this will create our table named "neuro_disorder_db" within postgresql
path = (f"postgresql://postgres:{password}@localhost:5432/neuro_disorder_db")
engine = create_engine(path, echo=True)
Base.metadata.create_all(engine)
# Out:
# 2022-01-14 22:55:46,450 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2022-01-14 22:55:46,451 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-01-14 22:55:46,457 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-01-14 22:55:46,458 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-01-14 22:55:46,481 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-01-14 22:55:46,485 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-01-14 22:55:46,503 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-01-14 22:55:46,506 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-01-14 22:55:46,507 INFO sqlalchemy.engine.Engine [generated in 0.00153s] {'name': 'disorders'}
# 2022-01-14 22:55:46,527 INFO sqlalchemy.engine.Engine
# CREATE TABLE disorders (
# 	index SERIAL NOT NULL,
# 	code VARCHAR,
# 	diagnosis VARCHAR,
# 	entity VARCHAR,
# 	population FLOAT,
# 	prevalence_in_females FLOAT,
# 	prevalence_in_males FLOAT,
# 	year INTEGER,
# 	PRIMARY KEY (index)
# )
#
#
# 2022-01-14 22:55:46,529 INFO sqlalchemy.engine.Engine [no key 0.00232s] {}
# 2022-01-14 22:55:46,629 INFO sqlalchemy.engine.Engine COMMIT

# %%
# this exports our 'final_table' dataframe to a csv file, so that once our table is created using the above code,
# the user will only need to import the csv file containing all our data listed below into the postgresql table
final_table.to_csv('final_table_clean.csv', index=False)
